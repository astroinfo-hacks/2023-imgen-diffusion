# %% [markdown]
# # Preprocessing and data set creation

# %%
import matplotlib.pyplot as plt

from astropy.visualization import astropy_mpl_style

plt.style.use(astropy_mpl_style)

# %%
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename


images = []



image_file = get_pkg_data_filename('../data/shalo_091-0_v0_photo.fits')

# %%
fits.info(image_file)
# Out:
# Filename: ../data/shalo_091-0_v0_photo.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  CFHT_MEGACAM.U    1 PrimaryHDU      30   (5000, 5000)   float32
#   1  SUBARU_HSC.G    1 ImageHDU        31   (5000, 5000)   float32
#   2  SUBARU_HSC.R    1 ImageHDU        31   (5000, 5000)   float32
#   3  CFHT_MEGACAM.R    1 ImageHDU        31   (5000, 5000)   float32
#   4  SUBARU_HSC.I    1 ImageHDU        31   (5000, 5000)   float32
#   5  SUBARU_HSC.Z    1 ImageHDU        31   (5000, 5000)   float32
#   6  SUBARU_HSC.Y    1 ImageHDU        31   (5000, 5000)   float32

# %%
fits.getheader(image_file)
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 5000
# NAXIS2  =                 5000
# EXTEND  =                    T
# EXTNAME = 'CFHT_MEGACAM.U'     / extension name
# ORIGIN  = 'SKIRT 9 Simulation' / Image origin
# SIMTAG  = 'TNG50-1 '           / Simulation name
# SNAPNUM =                   91 / Simulation snapshot
# SUBHALO =                    0 / Subhalo ID
# CAMERA  = 'v0      '           / Camera ID
# INCL    =                109.5 / Camera inclination
# AZIM    =                  0.0 / Camera azimuth
# ROLL    =                  0.0 / Camera roll
# COSMO   = 'Planck15'           / Cosmology
# REDSHIFT=               0.0994 / Redshift
# FILTER  = 'CFHT_MegaCam.u'     / Filter name
# NPACKET =         1000000000.0 / Number of photon packets
# WLPIVOT =         0.3676117137 / Pivot wavelength (micron)
# ...

# %%
image_data_list = []

image_data = fits.getdata(image_file, ext=0)
image_data_1 = fits.getdata(image_file, ext=1)
image_data_2 = fits.getdata(image_file, ext=2)
image_data_3 = fits.getdata(image_file, ext=3)

# %%
image_data
# Out:
# array([[27.82555 , 29.72247 , 99.      , ..., 99.      , 99.      ,
#         99.      ],
#        [99.      , 99.      , 99.      , ..., 99.      , 99.      ,
#         99.      ],
#        [99.      , 99.      , 99.      , ..., 99.      , 99.      ,
#         99.      ],
#        ...,
#        [99.      , 99.      , 99.      , ..., 99.      , 99.      ,
#         29.867613],
#        [99.      , 99.      , 99.      , ..., 27.53873 , 27.980803,
#         99.      ],
#        [99.      , 99.      , 99.      , ..., 30.07442 , 99.      ,
#         99.      ]], dtype=float32)

# %%
print(image_data.shape)
# Out:
# (5000, 5000)

# %%
fig, axs = plt.subplots(2, 2)
axs[0,0].imshow(image_data)
axs[0,1].imshow(image_data_1)
axs[1,0].imshow(image_data_2)
axs[1,1].imshow(image_data_3)
fig.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       4 axs[1,0].imshow(image_data_2)
#       5 axs[1,1].imshow(image_data_3)
# ----> 6 fig.colorbar()
#
# TypeError: colorbar() missing 1 required positional argument: 'mappable'
